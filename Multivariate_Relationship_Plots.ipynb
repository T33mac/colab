# %% [markdown]
# <a href="https://colab.research.google.com/github/T33mac/colab-projects/blob/master/Multivariate_Relationship_Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig, ax = plt.subplots(figsize=(10.5, 7.2))

sns.regplot(x='total_bill', y='tip', data=tips, color='#F15B2A', ax=ax)

# %%
fig, ax = plt.subplots(figsize=(10.5, 7.2))

sns.scatterplot(x='total_bill', y='tip', data=tips, color='#F15B2A', ax=ax)

# %%
#bubble plot
sns.lmplot(x='total_bill', y='tip', data=tips,
           scatter_kws={'s':tips['size']*20},
           fit_reg=False)

# %%
x = np.random.rand(40)
y = np.random.rand(40)
z = np.random.rand(40)

x = tips.total_bill
y = tips.tip
z = np.arange(len(x))

fig = plt.figure(figsize=(10.5, 7.2))
plt.scatter(x, y, s=z*1.5, alpha=0.5, c='#F15B2A')
